# %%
import pandas as pd
import re
import xlrd
import os
import xlwt

# %%
def Get_Nutrition_Info(nutrition_info):
    m = re.search(r'(((Crude Fat)|(Total Calories)|(Crude Fiber)|(Moisture)|(Crude Protein)):[ ]*[\d]+[.]*[\d]*((kcal)|(%)))+', nutrition_info)
    if m:
        return m.group()
    else:
        return ""

# %%
file_path = './PetFoodNutritionFact.xls'
data = pd.read_excel(file_path, header = 0)
products_name = data.values[:,1]
nutritions_info = data.values[:,2]
    

workbook = xlwt.Workbook(encoding='utf-8')
worksheet = workbook.add_sheet('Worksheet')

# %%
for i in range(len(products_name)):
    try:
        product_name = products_name[i]
        # 写入excel参数对应 行, 列, 值
        worksheet.write(i, 0, label=product_name)
        nutrition_info_list = nutritions_info[i].split(",")
        new_nutrition_info_list = list()
        line = 1
        for j in range(len(nutrition_info_list)):
            current_cell_info = Get_Nutrition_Info(nutrition_info_list[j].strip())
            if (current_cell_info):
                worksheet.write(i, line, label=current_cell_info)
                line += 1
    except:
        print("get wrong")
# Out:
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong
# get wrong

# %%
workbook.save('./PetFoodNutritionFactDataAnalysis.xls')
